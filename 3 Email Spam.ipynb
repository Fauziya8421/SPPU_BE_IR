# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
import string
from string import punctuation
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# Download NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Load the dataset
df = pd.read_csv('email.csv')
df
# Out:
#             Category                                            Message
# 0                ham  Go until jurong point, crazy.. Available only ...
# 1                ham                      Ok lar... Joking wif u oni...
# 2               spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3                ham  U dun say so early hor... U c already then say...
# 4                ham  Nah I don't think he goes to usf, he lives aro...
# ...              ...                                                ...
# 5568             ham               Will ü b going to esplanade fr home?
# 5569             ham  Pity, * was in mood for that. So...any other s...
# 5570             ham  The guy did some bitching but I acted like i'd...
# 5571             ham                         Rofl. Its true to its name
# 5572  {"mode":"full"                                    isActive:false}
#
# [5573 rows x 2 columns]

# %%
# Data Preprocessing: Drop duplicates and check for null values
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %%
# Download NLTK stopwords if not already downloaded
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Function to preprocess text by removing punctuation and stopwords
def process(text):
    tokens = word_tokenize(text.lower())
    stop_words = set(list(stopwords.words('english') + list(punctuation)))
    ft = [word for word in tokens if word.isalnum() and word not in stop_words]
    return ft

# %%
# Vectorize the text data using CountVectorizer with the custom analyzer
cv = CountVectorizer(analyzer=process)
X = cv.fit_transform(df['Message'])

# %%
# Preprocessing
# Convert labels to binary format: 'spam' -> 1, 'ham' -> 0
df['label'] = df['Category'].map({'spam': 1, 'ham': 0})

# %%
df.dropna(inplace= True)

# %%
# Define the target variable
y = df['label']
X = cv.fit_transform(df['Message'])

# %%
# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Train the Naive Bayes classifier
cl = MultinomialNB()
cl.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
# Predict on the test set
pred_test = cl.predict(x_test)

# %%
# Evaluate the model
print("Classification Report:")
print(classification_report(y_test, pred_test))
print("Confusion Matrix:")
print(confusion_matrix(y_test, pred_test))
print("Accuracy Score:", accuracy_score(y_test, pred_test))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.99       897
#          1.0       0.89      0.92      0.91       135
#
#     accuracy                           0.97      1032
#    macro avg       0.94      0.95      0.95      1032
# weighted avg       0.98      0.97      0.97      1032
#
# Confusion Matrix:
# [[882  15]
#  [ 11 124]]
# Accuracy Score: 0.9748062015503876
